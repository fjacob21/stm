# %%
import osmnx as ox

# %%
import matplotlib.pyplot as plt

# %%
place_name = "Montreal, Canada"

# %%
graph = ox.graph_from_place(place_name)

# %%
fig, ax = ox.plot_graph(graph)

# %%
plt.tight_layout()

# %%
buildings = ox.buildings_from_place(place_name)

# %%
area = ox.gdf_from_place(place_name)

# %%
nodes, edges = ox.graph_to_gdfs(graph)

# %%
nodes.head()
# Out:
#            highway       osmid  ref          x          y  \
# 2178328716     NaN  2178328716  NaN -73.577708  45.565644
# 2178328717     NaN  2178328717  NaN -73.577211  45.566212
# 2178328718     NaN  2178328718  NaN -73.579560  45.567664
# 218234892      NaN   218234892  NaN -73.582921  45.555718
# 1307181070     NaN  1307181070  NaN -73.586224  45.477006
#
#                                          geometry
# 2178328716         POINT (-73.5777075 45.5656445)
# 2178328717          POINT (-73.5772113 45.566212)
# 2178328718  POINT (-73.57956009999999 45.5676643)
# 218234892          POINT (-73.5829215 45.5557175)
# 1307181070         POINT (-73.5862236 45.4770058)

# %%
fig, ax = plt.subplots()

# %%
area.plot(ax=ax, facecolor='black')

# %%
edges.plot(ax=ax, linewidth=1, edgecolor='#BC8F8F')

# %%
 plt.tight_layout()

# %%
buildings.plot(ax=ax, facecolor='khaki', alpha=0.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-65971f202ae8> in <module>()
# ----> 1 buildings.plot(ax=ax, facecolor='khaki', alpha=0.7)
#
# NameError: name 'buildings' is not defined

# %%
basic_stats = ox.basic_stats(graph)
print(basic_stats['circuity_avg'])

extended_stats = ox.extended_stats(graph)
print(extended_stats['pagerank_max_node'])
# Out:
# 1.066427800815148
# 110744815

# %%
basic_stats
# Out:
# {'n': 46508,
#  'm': 124569,
#  'k_avg': 5.3568848370172875,
#  'intersection_count': 42622,
#  'streets_per_node_avg': 3.117936699062527,
#  'streets_per_node_counts': {0: 0,
#   1: 3886,
#   2: 205,
#   3: 29878,
#   4: 11848,
#   5: 495,
#   6: 171,
#   7: 18,
#   8: 5,
#   9: 1,
#   10: 0,
#   11: 1},
#  'streets_per_node_proportion': {0: 0.0,
#   1: 0.08355551733035177,
#   2: 0.0044078438118173215,
#   3: 0.6424271093145265,
#   4: 0.25475187064591037,
#   5: 0.01064333017975402,
#   6: 0.003676786789369571,
#   7: 0.00038703018835469167,
#   8: 0.00010750838565408102,
#   9: 2.1501677130816204e-05,
#   10: 0.0,
#   11: 2.1501677130816204e-05},
#  'edge_length_total': 10522556.626999881,
#  'edge_length_avg': 84.47171147717233,
#  'street_length_total': 6391027.619999914,
#  'street_length_avg': 88.0306834710732,
#  'street_segments_count': 72600,
#  'node_density_km': None,
#  'intersection_density_km': None,
#  'edge_density_km': None,
#  'street_density_km': None,
# ...

# %%
G = ox.graph_from_place('Manhattan, New York, USA', network_type='drive')
ox.plot_graph(ox.project_graph(G))
# Out:
# (<Figure size 195.384x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x130588668>)

# %%
G = ox.graph_from_point((45.465438, -73.831355), distance=1550, network_type='all')
ox.plot_graph(G)
# Out:
# (<Figure size 609.524x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12d315208>)

# %%
G.
# Out:
# DiMultiDegreeView({412336190: 6, 412336191: 4, 412336192: 6, 4911415380: 6, 4911415389: 4, 4911415392: 6, 4911415393: 6, 4911415396: 6, 4911415397: 6, 4911415399: 8, 4911415400: 6, 4911415401: 6, 4911415402: 8, 4911415403: 6, 4911415404: 6, 4911415405: 8, 4911415406: 6, 4911415407: 6, 4911415408: 8, 4911415409: 6, 4911415410: 6, 4911415411: 8, 4911415412: 6, 4911415413: 6, 4911415414: 8, 4911415415: 6, 4911415416: 6, 4911415418: 6, 4911415419: 6, 4911415420: 2, 4483891493: 6, 4483891494: 2, 4483891495: 2, 4911415621: 6, 4911415622: 2, 4911415623: 6, 4911415625: 2, 1975140710: 5, 109920725: 6, 1960952304: 5, 1951941119: 6, 1951941135: 6, 96059948: 3, 2635399753: 4, 4571284077: 6, 4571284079: 8, 4571284081: 8, 4571284083: 6, 174244528: 6, 110641945: 6, 110641954: 4, 110641959: 4, 110641964: 6, 5773116269: 6, 4688757626: 6, 4688757628: 6, 96060293: 3, 5344773010: 3, 5344773012: 4, 96060386: 3, 116130821: 6, 280888472: 6, 280888571: 6, 1766540537: 4, 1766540538: 6, 1990149397: 6, 4516595
# ...
